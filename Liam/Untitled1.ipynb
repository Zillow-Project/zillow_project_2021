# %%
import warnings
warnings.filterwarnings("ignore")

import env
import Liam_wrangle
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import viz_kmeans
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy import stats

import sklearn.preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('train_zillow.csv')

# %%
def split_zillow(df):
    '''This fuction takes in a df 
    splits into train, test, validate
    return: three pandas dataframes: train, validate, test
    '''
    # split the focused zillow data
    train_validate, test = train_test_split(df, test_size=.2, random_state=1234)
    train, validate = train_test_split(train_validate, test_size=.3, random_state=1234)
    return train, validate, test

# %%
train, validate, test = split_zillow(df)

# %%
def scale_my_data(train, validate, test):
    scale_columns = ['bathrooms', 'bedrooms', 'quality', 
              'square_feet', 'full_bathrooms', 
              'latitude', 'longitude', 'lot_square_feet',  
              'land_type', 'city', 'county', 'zip_code', 
             'room_count', 'unitcnt', 'structure_tax_value', 
             'tax_value',  'land_tax_value', 'taxamount',
              'house_age', 'tax_rate', 'acres']
    scaler = MinMaxScaler()
    scaler.fit(train[scale_columns])

    train_scaled = scaler.transform(train[scale_columns])
    validate_scaled = scaler.transform(validate[scale_columns])
    test_scaled = scaler.transform(test[scale_columns])
    #turn into dataframe
    train_scaled = pd.DataFrame(train_scaled)
    validate_scaled = pd.DataFrame(validate_scaled)
    test_scaled = pd.DataFrame(test_scaled)
    
    return train_scaled, validate_scaled, test_scaled

# %%
train_scaled, validate_scaled, test_scaled = scale_my_data(train, validate, test)

# %%
from viz_kmeans import start_longitude_latitude_houseage

# %%
train, validate, test = start_longitude_latitude_houseage(train, validate, test)

# %%
train.head()
# Out:
#        parcelid  land_type  has_heating_system  bathrooms  bedrooms  quality  \
# 18796  12086611      266.0                   1        2.0       3.0      8.0
# 3518   17086463      261.0                   0        3.0       4.0      6.0
# 15170  10764495      266.0                   1        3.0       2.0      8.0
# 13451  11080027      261.0                   1        2.0       3.0      8.0
# 28664  14225001      261.0                   0        2.0       4.0      6.0
#
#        square_feet    fips  has_fireplace  full_bathrooms  ...  \
# 18796       1543.0  6037.0            0.0             2.0  ...
# 3518        1719.0  6111.0            1.0             3.0  ...
# 15170       1170.0  6037.0            0.0             3.0  ...
# 13451       2049.0  6037.0            0.0             2.0  ...
# 28664       1660.0  6059.0            1.0             2.0  ...
#
#        in_orange_county  in_ventura  house_age   tax_rate     acres  \
# 18796                 0           0       37.0  81.643225  0.510560
# 3518                  0           1       64.0  93.685084  0.189991
# 15170                 0           0       42.0  80.349200  3.348600
# 13451                 0           0       47.0  79.989777  0.268939
# 28664                 1           0       59.0  89.914255  0.195133
#
#        level_of_log_error  square_feet_bins  lot_sqft_bins  acre_bins  \
# 18796            Accurate           1.5l-2k        20k-30k       0-15
# 3518             Accurate           1.5l-2k          0-10k       0-15
# 15170            Accurate           1k-1.5k            70+       0-15
# 13451            Accurate           2k-2.5k        10k-20k       0-15
# 28664            Accurate           1.5l-2k          0-10k       0-15
#
#        longitude_latitude_houseage_cluster
# 18796                                    1
# 3518                                     3
# 15170                                    4
# 13451                                    4
# 28664                                    2
#
# [5 rows x 35 columns]

# %%
from viz_kmeans import predict_cluster_longitude_latitude_houseage

# %%
predict_cluster_longitude_latitude_houseage(train)
