# %%
import wrangle
import pandas as pd

# %%
df = pd.read_csv("zillow.csv")
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (37,38,63,67,68) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.isnull().sum()
# Out:
# land_type              0
# has_heating_system     0
# bathrooms              0
# bedrooms               0
# quality                0
# square_feet            0
# fips                   0
# has_fireplace          0
# full_bathrooms         0
# latitude               0
# longitude              0
# lot_square_feet        0
# has_pool               0
# city                   0
# county                 0
# zip_code               0
# room_count             0
# unitcnt                0
# yearbuilt              0
# structure_tax_value    0
# tax_value              0
# land_tax_value         0
# taxamount              0
# logerror               0
# propertylandusedesc    0
# in_los_angeles         0
# in_orange_county       0
# in_ventura             0
# house_age              0
# tax_rate               0
# level_of_log_error     0
# acres                  0
# dtype: int64

# %%
df.head()
# Out:
#           land_type  has_heating_system  bathrooms  bedrooms  quality  \
# parcelid
# 10711855      261.0                   1        2.0       3.0      8.0
# 10711877      261.0                   1        2.0       4.0      8.0
# 10711888      261.0                   1        2.0       4.0      8.0
# 10711910      261.0                   1        2.0       3.0      8.0
# 10711923      261.0                   1        2.0       4.0      8.0
#
#           square_feet    fips  has_fireplace  full_bathrooms    latitude  ...  \
# parcelid                                                                  ...
# 10711855       2107.0  6037.0            0.0             2.0  34222559.0  ...
# 10711877       1882.0  6037.0            0.0             2.0  34220261.0  ...
# 10711888       1882.0  6037.0            0.0             2.0  34222491.0  ...
# 10711910       1477.0  6037.0            0.0             2.0  34221864.0  ...
# ...
