# %%
import wrangle
import pandas as pd
import env

# %%
df = pd.read_csv("zillow.csv")
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (37,38,63,67,68) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df = wrangle.clean_zillow(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64068 entries, 10711855 to 162960814
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   land_type            64068 non-null  float64
#  1   has_heating_system   64068 non-null  int64
#  2   bathrooms            64068 non-null  float64
#  3   bedrooms             64068 non-null  float64
#  4   quality              64068 non-null  float64
#  5   square_feet          64068 non-null  float64
#  6   fips                 64068 non-null  float64
#  7   has_fireplace        64068 non-null  float64
#  8   full_bathrooms       64068 non-null  float64
#  9   latitude             64068 non-null  float64
#  10  longitude            64068 non-null  float64
#  11  lot_square_feet      64068 non-null  float64
#  12  has_pool             64068 non-null  float64
#  13  city                 64068 non-null  float64
# ...

# %%
df.sample()
# Out:
#           land_type  has_heating_system  bathrooms  bedrooms  quality  \
# parcelid
# 12282097      261.0                   1        1.0       3.0      4.0
#
#           square_feet    fips  has_fireplace  full_bathrooms    latitude  ...  \
# parcelid                                                                  ...
# 12282097       1153.0  6037.0            0.0             1.0  33936433.0  ...
#
#           land_tax_value  taxamount  logerror  in_los_angeles  \
# parcelid
# 12282097         28469.0    1284.43 -0.064041               1
#
#           in_orange_county  in_ventura  house_age   tax_rate  \
# parcelid
# 12282097                 0           0       73.0  48.888612
#
#           level_of_log_error     acres
# parcelid
# 12282097                  L1  0.171511
#
# [1 rows x 31 columns]

# %%
df.info()
